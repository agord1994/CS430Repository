# %% [markdown]
# <a href="https://colab.research.google.com/github/agord1994/CS430Repository/blob/main/IntrotoPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# introduction to python

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
 df = pd.read_csv('/content/gdrive/MyDrive/CS430/processed_penguins.csv')

# %%
df.head()
# Out:
#   study_name species     island clutch_completion    date_egg  bill_length_mm  \
# 0    PAL0708  Adelie  Torgersen               Yes  11/11/2007            39.5
# 1    PAL0708  Adelie  Torgersen               Yes  11/16/2007            40.3
# 2    PAL0708  Adelie  Torgersen               Yes  11/16/2007            36.7
# 3    PAL0708  Adelie  Torgersen               Yes  11/16/2007            39.3
# 4    PAL0708  Adelie  Torgersen                No  11/15/2007            38.9
#
#    bill_depth_mm  flipper_length_mm  body_mass_g     sex  delta_15  delta_13  \
# 0           17.4                186         3800  FEMALE   8.94956 -24.69454
# 1           18.0                195         3250  FEMALE   8.36821 -25.33302
# 2           19.3                193         3450  FEMALE   8.76651 -25.32426
# 3           20.6                190         3650    MALE   8.66496 -25.29805
# 4           17.8                181         3625  FEMALE   9.18718 -25.21799
#
#    study_day
# 0          2
# 1          7
# 2          7
# 3          7
# 4          6

# %%
df.tail()
# Out:
#     study_name species  island clutch_completion    date_egg  bill_length_mm  \
# 319    PAL0910  Gentoo  Biscoe                No   12/1/2009            47.2
# 320    PAL0910  Gentoo  Biscoe               Yes  11/22/2009            46.8
# 321    PAL0910  Gentoo  Biscoe               Yes  11/22/2009            50.4
# 322    PAL0910  Gentoo  Biscoe               Yes  11/22/2009            45.2
# 323    PAL0910  Gentoo  Biscoe               Yes  11/22/2009            49.9
#
#      bill_depth_mm  flipper_length_mm  body_mass_g     sex  delta_15  \
# 319           13.7                214         4925  FEMALE   7.99184
# 320           14.3                215         4850  FEMALE   8.41151
# 321           15.7                222         5750    MALE   8.30166
# 322           14.8                212         5200  FEMALE   8.24246
# 323           16.1                213         5400    MALE   8.36390
#
#      delta_13  study_day
# 319 -26.20538        753
# 320 -26.13832        744
# 321 -26.04117        744
# 322 -26.11969        744
# 323 -26.15531        744

# %%
df.sample(5)
# Out:
#     study_name species     island clutch_completion    date_egg  \
# 17     PAL0708  Adelie     Biscoe               Yes  11/12/2007
# 282    PAL0809  Gentoo     Biscoe               Yes   11/9/2008
# 57     PAL0809  Adelie  Torgersen               Yes  11/14/2008
# 116    PAL0910  Adelie  Torgersen               Yes  11/18/2009
# 96     PAL0910  Adelie     Biscoe               Yes  11/20/2009
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex  \
# 17             40.6           18.6                183         3550    MALE
# 282            45.2           16.4                223         5950    MALE
# 57             33.5           19.0                190         3600  FEMALE
# 116            44.1           18.0                210         4000    MALE
# 96             43.2           19.0                197         4775    MALE
#
#      delta_15  delta_13  study_day
# 17    8.93997 -25.36288          3
# 282   8.19749 -26.65931        366
# 57    7.88863 -26.63085        371
# 116   9.10702 -26.01363        740
# 96    9.31735 -25.45171        742

# %% [markdown]
# **Basic Statistics**

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      324.000000     324.000000         324.000000   324.000000
# mean        44.053395      17.127469         201.216049  4213.966049
# std          5.480635       1.967385          13.958683   809.277529
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.575000         190.000000  3550.000000
# 50%         44.950000      17.300000         197.000000  4050.000000
# 75%         48.700000      18.600000         213.000000  4800.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#          delta_15    delta_13   study_day
# count  324.000000  324.000000  324.000000
# mean     8.739944  -25.688691  397.188272
# std      0.552073    0.790840  293.819607
# min      7.632200  -27.018540    0.000000
# 25%      8.304440  -26.326780   20.000000
# 50%      8.658585  -25.842775  367.500000
# 75%      9.181477  -25.055572  738.000000
# max     10.025440  -23.890170  753.000000

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.222923           0.648947
# bill_depth_mm           -0.222923       1.000000          -0.574924
# flipper_length_mm        0.648947      -0.574924           1.000000
# body_mass_g              0.591724      -0.470177           0.877066
# delta_15                -0.056942       0.599481          -0.501601
# delta_13                 0.188517       0.420012          -0.375570
# study_day                0.018592      -0.034719           0.133971
#
#                    body_mass_g  delta_15  delta_13  study_day
# bill_length_mm        0.591724 -0.056942  0.188517   0.018592
# bill_depth_mm        -0.470177  0.599481  0.420012  -0.034719
# flipper_length_mm     0.877066 -0.501601 -0.375570   0.133971
# body_mass_g           1.000000 -0.539795 -0.372041   0.014964
# delta_15             -0.539795  1.000000  0.569393   0.130083
# delta_13             -0.372041  0.569393  1.000000  -0.307982
# study_day             0.014964  0.130083 -0.307982   1.000000

# %%
df[['bill_length_mm','flipper_length_mm']].describe()
# Out:
#        bill_length_mm  flipper_length_mm
# count      324.000000         324.000000
# mean        44.053395         201.216049
# std          5.480635          13.958683
# min         32.100000         172.000000
# 25%         39.500000         190.000000
# 50%         44.950000         197.000000
# 75%         48.700000         213.000000
# max         59.600000         231.000000

# %%
df.bill_length_mm
# Out:
# 0      39.5
# 1      40.3
# 2      36.7
# 3      39.3
# 4      38.9
#        ...
# 319    47.2
# 320    46.8
# 321    50.4
# 322    45.2
# 323    49.9
# Name: bill_length_mm, Length: 324, dtype: float64

# %%
species= df['species'].groupby(df['species']).count()

# %%
island=df['island'].groupby(df['island']).count()

# %%
sex= df['sex'].groupby(df['sex']).count()

# %%
print(species)
# Out:
# species
# Adelie       139
# Chinstrap     67
# Gentoo       118
# Name: species, dtype: int64

# %%
island
# Out:
# island
# Biscoe       162
# Dream        119
# Torgersen     43
# Name: island, dtype: int64

# %%
sex
# Out:
# sex
# FEMALE    163
# MALE      161
# Name: sex, dtype: int64

# %% [markdown]
# **Data Types**

# %% [markdown]
# General Data Types Regardless of language or system
#
# *   **Nominal:**uses a label or name to distinguish one object from another zip code, gender = or not =
# *   **Ordinal:**using values to provide ordering of subjects opinion, grades < or>
# *  **Interval:** Uses units of measuremnt, but the origin is arbitrary (0 does not indicate an absence of something) Celsius or farenheit , calendar dates + or -
# *   **Ratio:** Use units of measurement, and the origin is not arbitrary and does indicate an absence of something. Temperature in kelvin,length,counts,age,income +,-,*/

# %%
df.dtypes
# Out:
# study_name            object
# species               object
# island                object
# clutch_completion     object
# date_egg              object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm      int64
# body_mass_g            int64
# sex                   object
# delta_15             float64
# delta_13             float64
# study_day              int64
# dtype: object

# %%
df.date_egg=pd.to_datetime(df.date_egg)

# %%
print(df.date_egg)
# Out:
# 0     2007-11-11
# 1     2007-11-16
# 2     2007-11-16
# 3     2007-11-16
# 4     2007-11-15
#          ...
# 319   2009-12-01
# 320   2009-11-22
# 321   2009-11-22
# 322   2009-11-22
# 323   2009-11-22
# Name: date_egg, Length: 324, dtype: datetime64[ns]

# %%
dates= df['date_egg'].groupby(df['date_egg']).count()

# %%
dates
# Out:
# date_egg
# 2007-11-09     4
# 2007-11-10     4
# 2007-11-11     1
# 2007-11-12     8
# 2007-11-13     3
# 2007-11-15     2
# 2007-11-16    13
# 2007-11-18     2
# 2007-11-19     4
# 2007-11-21     4
# 2007-11-22     2
# 2007-11-26     4
# 2007-11-27    18
# 2007-11-28     8
# 2007-11-29     8
# 2007-11-30     4
# 2007-12-03     6
# 2008-11-02     6
# 2008-11-03     8
# 2008-11-04    12
# 2008-11-05     2
# 2008-11-06    12
# 2008-11-07     2
# 2008-11-08     8
# 2008-11-09    15
# 2008-11-10     2
# 2008-11-11     4
# 2008-11-13    12
# 2008-11-14    10
# 2008-11-15     4
# 2008-11-17     4
# 2008-11-24     8
# 2008-11-25     4
# 2009-11-09     4
# 2009-11-10     4
# 2009-11-12     2
# 2009-11-13     4
# 2009-11-14     2
# 2009-11-15    10
# 2009-11-16    10
# 2009-11-17    10
# 2009-11-18    14
# 2009-11-19     2
# 2009-11-20     6
# 2009-11-21    12
# 2009-11-22    10
# 2009-11-23     6
# 2009-11-25     6
# 2009-11-27     9
# 2009-12-01     5
# Name: date_egg, dtype: int64

# %% [markdown]
# **Miscellaneous Pandas function**
#
# Here are examples of a few functiins that will come in handy.

# %%
df.query('species== "Adelie"')
# Out:
#     study_name species     island clutch_completion   date_egg  \
# 0      PAL0708  Adelie  Torgersen               Yes 2007-11-11
# 1      PAL0708  Adelie  Torgersen               Yes 2007-11-16
# 2      PAL0708  Adelie  Torgersen               Yes 2007-11-16
# 3      PAL0708  Adelie  Torgersen               Yes 2007-11-16
# 4      PAL0708  Adelie  Torgersen                No 2007-11-15
# ..         ...     ...        ...               ...        ...
# 134    PAL0910  Adelie      Dream               Yes 2009-11-13
# 135    PAL0910  Adelie      Dream               Yes 2009-11-17
# 136    PAL0910  Adelie      Dream               Yes 2009-11-17
# 137    PAL0910  Adelie      Dream               Yes 2009-11-17
# 138    PAL0910  Adelie      Dream               Yes 2009-11-17
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex  \
# 0              39.5           17.4                186         3800  FEMALE
# 1              40.3           18.0                195         3250  FEMALE
# 2              36.7           19.3                193         3450  FEMALE
# 3              39.3           20.6                190         3650    MALE
# 4              38.9           17.8                181         3625  FEMALE
# ..              ...            ...                ...          ...     ...
# 134            36.6           18.4                184         3475  FEMALE
# 135            36.0           17.8                195         3450  FEMALE
# 136            37.8           18.1                193         3750    MALE
# 137            36.0           17.1                187         3700  FEMALE
# 138            41.5           18.5                201         4000    MALE
#
#      delta_15  delta_13  study_day
# 0     8.94956 -24.69454          2
# 1     8.36821 -25.33302          7
# 2     8.76651 -25.32426          7
# 3     8.66496 -25.29805          7
# 4     9.18718 -25.21799          6
# ..        ...       ...        ...
# 134   8.68744 -25.83060        735
# 135   8.94332 -25.79189        739
# 136   8.97533 -26.03495        739
# 137   8.93465 -26.07081        739
# 138   8.89640 -26.06967        739
#
# [139 rows x 13 columns]

# %% [markdown]
# **Miscellneous Pandas Function**

# %%
chinstrap= df.query('species=="Chinstrap"')

# %%
chinstrap.head()
# Out:
#     study_name    species island clutch_completion   date_egg  bill_length_mm  \
# 139    PAL0708  Chinstrap  Dream                No 2007-11-19            46.5
# 140    PAL0708  Chinstrap  Dream                No 2007-11-19            50.0
# 141    PAL0708  Chinstrap  Dream               Yes 2007-11-26            51.3
# 142    PAL0708  Chinstrap  Dream               Yes 2007-11-26            45.4
# 143    PAL0708  Chinstrap  Dream               Yes 2007-11-21            52.7
#
#      bill_depth_mm  flipper_length_mm  body_mass_g     sex  delta_15  \
# 139           17.9                192         3500  FEMALE   9.03935
# 140           19.5                196         3900    MALE   8.92069
# 141           19.2                193         3650    MALE   9.29078
# 142           18.7                188         3525  FEMALE   8.64701
# 143           19.8                197         3725    MALE   9.00642
#
#      delta_13  study_day
# 139 -24.30229         10
# 140 -24.23592         10
# 141 -24.75570         17
# 142 -24.62717         17
# 143 -24.61867         12

# %%
df.rename(columns={'island':'location'},inplace=True)

# %%
df.drop(['study_name','clutch_completion','delta_15','delta_13','study_day','date_egg','location'],axis=1,inplace=True)

# %% [markdown]
# **Using Matplotlib to Visualize Data**

# %%
df.plot(kind='scatter',x='bill_length_mm',y='bill_depth_mm',figsize=(20,10))

# %%
df.plot(kind='scatter',x='bill_length_mm',y='flipper_length_mm',figsize=(20,10))

# %% [markdown]
# we can put several plots into one figure

# %%
fig= plt.figure(figsize=(20,10))
fig.add_axes()
ax1=fig.add_subplot(221)
ax2= fig.add_subplot(222)
ax3= fig.add_subplot(223)
ax4= fig.add_subplot(224)

df.plot(kind='scatter', x='bill_length_mm',y='flipper_length_mm',title="Bill Length vs. Flipper Length", ax=ax1)
df.plot(kind='scatter', x='bill_length_mm',y='bill_depth_mm',title="Bill Length vs. Bill Depth", ax=ax2)
df.plot(kind='scatter', x='bill_length_mm',y='body_mass_g',title="Bill Length vs. body mass", ax=ax3)
df.plot(kind='scatter', x='flipper_length_mm',y='body_mass_g',title="Flipper Length vs. body mass", ax=ax4)

fig.tight_layout()

# %%
fig= plt.figure(figsize=(20,10))
fig.add_axes()
ax1= fig.add_subplot(221)
ax2=fig.add_subplot(222)
ax3=fig.add_subplot(223)

species.plot(kind='barh', color='red', ax=ax1)
island.plot(kind='barh', color='blue',ax=ax2)
sex.plot(kind='barh', color='green',ax=ax3)

fig.tight_layout()

# %%
fig= plt.figure(figsize=(20,20))
dates.plot(kind='barh', title="Number of Eggs per Collection Date")

# %% [markdown]
# **Using Seaborn to Visualize Data**

# %%
fig= plt.figure(figsize=(20,10))

sns.scatterplot( x="flipper_length_mm", y="body_mass_g", data=df, hue="species")

# %%
fig= plt.figure(figsize=(20,10))
sns.scatterplot(x='bill_length_mm',y='bill_depth_mm',data=df, hue='species')

# %%
sns.set(rc={"figure.figsize":(20,10)})

fig,axes= plt.subplots(2,2)
sns.scatterplot(x='bill_length_mm', y='flipper_length_mm',data=df, hue='species',legend=False,ax=axes[0,0])
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm',data=df, hue='species',legend=False,ax=axes[0,1])
sns.scatterplot(x='bill_length_mm', y='body_mass_g',data=df, hue='species',legend=False,ax=axes[1,0])
sns.scatterplot(x='flipper_length_mm', y='body_mass_g',data=df, hue='species',legend=False,ax=axes[1,1])

# %%
sns.pairplot(df,hue="species",diag_kind="kde")

# %%
fig= plt.figure(figsize=(20,10))
sns.boxplot(x="species", y="body_mass_g", data=df, hue="species")

# %%
sns.violinplot(x="species", y="body_mass_g", data=df, hue="species")

# %% [markdown]
# **bank dataset**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#Using the separator parameter because this data is separated by semicolons
df = pd.read_csv('/content/gdrive/MyDrive/CS430/bank-full.csv', sep=';')

# %%
df.sample(10)
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 19428  32;"management";"married";"tertiary";"no";71;"...
# 22687  48;"management";"single";"tertiary";"no";830;"...
# 3227   44;"management";"married";"tertiary";"no";1033...
# 26995  30;"management";"single";"secondary";"no";4642...
# 11109  49;"management";"married";"primary";"no";1330;...
# 43359  57;"housemaid";"married";"primary";"no";780;"n...
# 32746  43;"blue-collar";"divorced";"secondary";"no";-...
# 44016  45;"management";"married";"unknown";"no";2724;...
# 30394  58;"retired";"single";"secondary";"no";-158;"y...
# 25429  42;"blue-collar";"married";"secondary";"no";68...

# %%
df.tail()
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...

# %%
df.describe()
# Out:
#        age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# count                                               45211
# unique                                              45211
# top     58;"management";"married";"tertiary";"no";2143...
# freq                                                    1
